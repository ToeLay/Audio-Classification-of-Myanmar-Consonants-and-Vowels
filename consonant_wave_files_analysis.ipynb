# %%
import librosa
import librosa.display
from pathlib import Path
import numpy as np
from matplotlib import pyplot as plt

# %%
def plot_audio(clip, sample_rate, title):
  timesteps = np.arange(len(clip)) / sample_rate  # in seconds

  plt.figure(figsize=(12, 4))
  
  # plot the entire clip 
  plt.plot(timesteps, clip)
  plt.xlabel('Time (s)')
  plt.ylabel('Amplitude')
  plt.title('Raw Audio: {} ({} samples)'.format(title, len(clip)))
  plt.show()

# %%
def plot_spectrogram(clip, sample_rate, title):
  n_fft = 1024
  hop_length = 512
  # number of mel frequency bands 
  n_mels = 64

  plt.figure(figsize=(12, 4))
  
  fmin = 20           
  fmax = sample_rate // 2
  mel_spec = librosa.feature.melspectrogram(clip, n_fft=n_fft, hop_length=hop_length,
                                          n_mels=n_mels, sr=sample_rate, power=1.0,
                                          fmin=fmin, fmax=fmax)
  mel_spec_db = librosa.amplitude_to_db(mel_spec, ref=np.max)
  librosa.display.specshow(mel_spec_db, x_axis='time',  y_axis='mel', 
                         sr=sample_rate, hop_length=hop_length, 
                         fmin=fmin, fmax=fmax)
  plt.title(f'n_mels=64, fmin=20, fmax=8000, {title}, (2D resulting shape : {mel_spec_db.shape})')
  plt.show()

# %% [markdown]
# #Analysis of consonants

# %%
data_path = Path('wave/consonant')

# %% [markdown]
# select one wave file from each class

# %%
paths = [next((_dir/(str(_dir).split('/')[-1]+'_1')).iterdir()) for _dir in data_path.iterdir()]
paths
# Out:
# [PosixPath('wave/consonant/12/12_1/2018-11-12-19:04:17.16khz.mono.wav'),
#  PosixPath('wave/consonant/21/21_1/2018-11-13-12:24:08.16khz.mono.wav'),
#  PosixPath('wave/consonant/3/3_1/2018-11-12-14:50:41.16khz.mono.wav'),
#  PosixPath('wave/consonant/22/22_1/2018-11-13-12:28:56.16khz.mono.wav'),
#  PosixPath('wave/consonant/17/17_1/2018-11-12-19:59:10.16khz.mono.wav'),
#  PosixPath('wave/consonant/11/11_1/2018-11-12-18:49:43.16khz.mono.wav'),
#  PosixPath('wave/consonant/18/18_1/2018-11-12-20:04:23.16khz.mono.wav'),
#  PosixPath('wave/consonant/8/8_1/2018-11-12-16:07:02.16khz.mono.wav'),
#  PosixPath('wave/consonant/1/1_1/2018-11-12-13:49:22.16khz.mono.wav'),
#  PosixPath('wave/consonant/5/5_1/2018-11-12-15:22:02.16khz.mono.wav'),
#  PosixPath('wave/consonant/13/13_1/2018-11-12-19:16:16.16khz.mono.wav'),
#  PosixPath('wave/consonant/16/16_1/2018-11-12-19:49:39.16khz.mono.wav'),
#  PosixPath('wave/consonant/4/4_1/2018-11-12-15:04:41.16khz.mono.wav'),
#  PosixPath('wave/consonant/14/14_1/2018-11-12-19:24:14.16khz.mono.wav'),
#  PosixPath('wave/consonant/15/15_1/2018-11-12-19:38:47.16khz.mono.wav'),
#  PosixPath('wave/consonant/9/9_1/2018-11-12-16:19:57.16khz.mono.wav'),
#  PosixPath('wave/consonant/7/7_1/2018-11-12-15:57:22.16khz.mono.wav'),
#  PosixPath('wave/consonant/20/20_1/2018-11-13-12:38:11.16khz.mono.wav'),
#  PosixPath('wave/consonant/2/2_1/2018-11-12-14:17:26.16khz.mono.wav'),
#  PosixPath('wave/consonant/10/10_1/2018-11-12-16:25:42.16khz.mono.wav'),
#  PosixPath('wave/consonant/6/6_1/2018-11-12-15:34:38.16khz.mono.wav'),
#  PosixPath('wave/consonant/19/19_1/2018-11-13-12:12:27.16khz.mono.wav')]

# %% [markdown]
# sort file paths for easier access

# %%
paths = sorted(paths, key=lambda x: int(str(x).split('/')[-3]))

# %% [markdown]
# #Index : 0, Class label : 1, Consonant : 'က'

# %%
wave_file = paths[0]

clip, sample_rate = librosa.load(wave_file, sr=None)
print('Sample Rate   {} Hz'.format(sample_rate))
print('Clip Length   {:3.2f} seconds'.format(librosa.get_duration(clip, sample_rate)))

trimmed_clip, _ = librosa.effects.trim(clip, top_db=10, frame_length=256, hop_length=128)
print('Trimmed clip Length   {:3.2f} seconds'.format(librosa.get_duration(trimmed_clip, sample_rate)))

plot_audio(clip, sample_rate, wave_file)
plot_audio(trimmed_clip, sample_rate, str(wave_file) + ' trimmed')

plot_spectrogram(clip, sample_rate, 'original')
plot_spectrogram(trimmed_clip, sample_rate, 'trimmed')
# Out:
# Sample Rate   16000 Hz
# Clip Length   1.38 seconds
# Trimmed clip Length   0.09 seconds

# %% [markdown]
# #Index : 1, Class label : 2, Consonant : 'ခ'

# %%
wave_file = paths[1]

clip, sample_rate = librosa.load(wave_file, sr=None)
print('Sample Rate   {} Hz'.format(sample_rate))
print('Clip Length   {:3.2f} seconds'.format(librosa.get_duration(clip, sample_rate)))

trimmed_clip, _ = librosa.effects.trim(clip, top_db=10, frame_length=256, hop_length=128)
print('Trimmed clip Length   {:3.2f} seconds'.format(librosa.get_duration(trimmed_clip, sample_rate)))

plot_audio(clip, sample_rate, wave_file)
plot_audio(trimmed_clip, sample_rate, str(wave_file) + ' trimmed')

plot_spectrogram(clip, sample_rate, 'original')
plot_spectrogram(trimmed_clip, sample_rate, 'trimmed')
# Out:
# Sample Rate   16000 Hz
# Clip Length   1.19 seconds
# Trimmed clip Length   0.10 seconds

# %% [markdown]
# #Index : 2, Class label : 3, Consonant : 'ဂ၊ ဃ'

# %%
wave_file = paths[2]

clip, sample_rate = librosa.load(wave_file, sr=None)
print('Sample Rate   {} Hz'.format(sample_rate))
print('Clip Length   {:3.2f} seconds'.format(librosa.get_duration(clip, sample_rate)))

trimmed_clip, _ = librosa.effects.trim(clip, top_db=10, frame_length=256, hop_length=128)
print('Trimmed clip Length   {:3.2f} seconds'.format(librosa.get_duration(trimmed_clip, sample_rate)))

plot_audio(clip, sample_rate, wave_file)
plot_audio(trimmed_clip, sample_rate, str(wave_file) + ' trimmed')

plot_spectrogram(clip, sample_rate, 'original')
plot_spectrogram(trimmed_clip, sample_rate, 'trimmed')
# Out:
# Sample Rate   16000 Hz
# Clip Length   0.98 seconds
# Trimmed clip Length   0.42 seconds

# %% [markdown]
# #Index : 3, Class label : 4, Consonant : 'င'

# %%
wave_file = paths[3]

clip, sample_rate = librosa.load(wave_file, sr=None)
print('Sample Rate   {} Hz'.format(sample_rate))
print('Clip Length   {:3.2f} seconds'.format(librosa.get_duration(clip, sample_rate)))

trimmed_clip, _ = librosa.effects.trim(clip, top_db=10, frame_length=256, hop_length=128)
print('Trimmed clip Length   {:3.2f} seconds'.format(librosa.get_duration(trimmed_clip, sample_rate)))

plot_audio(clip, sample_rate, wave_file)
plot_audio(trimmed_clip, sample_rate, str(wave_file) + ' trimmed')

plot_spectrogram(clip, sample_rate, 'original')
plot_spectrogram(trimmed_clip, sample_rate, 'trimmed')
# Out:
# Sample Rate   16000 Hz
# Clip Length   1.19 seconds
# Trimmed clip Length   0.22 seconds

# %% [markdown]
# #Index : 4, Class label : 5, Consonant : 'စ'

# %%
wave_file = paths[4]

clip, sample_rate = librosa.load(wave_file, sr=None)
print('Sample Rate   {} Hz'.format(sample_rate))
print('Clip Length   {:3.2f} seconds'.format(librosa.get_duration(clip, sample_rate)))

trimmed_clip, _ = librosa.effects.trim(clip, top_db=10, frame_length=256, hop_length=128)
print('Trimmed clip Length   {:3.2f} seconds'.format(librosa.get_duration(trimmed_clip, sample_rate)))

plot_audio(clip, sample_rate, wave_file)
plot_audio(trimmed_clip, sample_rate, str(wave_file) + ' trimmed')

plot_spectrogram(clip, sample_rate, 'original')
plot_spectrogram(trimmed_clip, sample_rate, 'trimmed')
# Out:
# Sample Rate   16000 Hz
# Clip Length   0.99 seconds
# Trimmed clip Length   0.14 seconds

# %% [markdown]
# #Index : 5, Class label : 6, Consonant : 'ဆ'

# %%
wave_file = paths[5]

clip, sample_rate = librosa.load(wave_file, sr=None)
print('Sample Rate   {} Hz'.format(sample_rate))
print('Clip Length   {:3.2f} seconds'.format(librosa.get_duration(clip, sample_rate)))

trimmed_clip, _ = librosa.effects.trim(clip, top_db=10, frame_length=256, hop_length=128)
print('Trimmed clip Length   {:3.2f} seconds'.format(librosa.get_duration(trimmed_clip, sample_rate)))

plot_audio(clip, sample_rate, wave_file)
plot_audio(trimmed_clip, sample_rate, str(wave_file) + ' trimmed')

plot_spectrogram(clip, sample_rate, 'original')
plot_spectrogram(trimmed_clip, sample_rate, 'trimmed')
# Out:
# Sample Rate   16000 Hz
# Clip Length   0.98 seconds
# Trimmed clip Length   0.10 seconds

# %% [markdown]
# #Index : 6, Class label : 7, Consonant : 'ဇ၊ ဈ'

# %%
wave_file = paths[6]

clip, sample_rate = librosa.load(wave_file, sr=None)
print('Sample Rate   {} Hz'.format(sample_rate))
print('Clip Length   {:3.2f} seconds'.format(librosa.get_duration(clip, sample_rate)))

trimmed_clip, _ = librosa.effects.trim(clip, top_db=10, frame_length=256, hop_length=128)
print('Trimmed clip Length   {:3.2f} seconds'.format(librosa.get_duration(trimmed_clip, sample_rate)))

plot_audio(clip, sample_rate, wave_file)
plot_audio(trimmed_clip, sample_rate, str(wave_file) + ' trimmed')

plot_spectrogram(clip, sample_rate, 'original')
plot_spectrogram(trimmed_clip, sample_rate, 'trimmed')
# Out:
# Sample Rate   16000 Hz
# Clip Length   0.99 seconds
# Trimmed clip Length   0.13 seconds

# %% [markdown]
# #Index : 7, Class label : 8, Consonant : 'ည၊ ဉ'

# %%
wave_file = paths[7]

clip, sample_rate = librosa.load(wave_file, sr=None)
print('Sample Rate   {} Hz'.format(sample_rate))
print('Clip Length   {:3.2f} seconds'.format(librosa.get_duration(clip, sample_rate)))

trimmed_clip, _ = librosa.effects.trim(clip, top_db=10, frame_length=256, hop_length=128)
print('Trimmed clip Length   {:3.2f} seconds'.format(librosa.get_duration(trimmed_clip, sample_rate)))

plot_audio(clip, sample_rate, wave_file)
plot_audio(trimmed_clip, sample_rate, str(wave_file) + ' trimmed')

plot_spectrogram(clip, sample_rate, 'original')
plot_spectrogram(trimmed_clip, sample_rate, 'trimmed')
# Out:
# Sample Rate   16000 Hz
# Clip Length   0.99 seconds
# Trimmed clip Length   0.18 seconds

# %% [markdown]
# #Index : 8, Class label : 9, Consonant : 'တ၊ ဋ'

# %%
wave_file = paths[8]

clip, sample_rate = librosa.load(wave_file, sr=None)
print('Sample Rate   {} Hz'.format(sample_rate))
print('Clip Length   {:3.2f} seconds'.format(librosa.get_duration(clip, sample_rate)))

trimmed_clip, _ = librosa.effects.trim(clip, top_db=10, frame_length=256, hop_length=128)
print('Trimmed clip Length   {:3.2f} seconds'.format(librosa.get_duration(trimmed_clip, sample_rate)))

plot_audio(clip, sample_rate, wave_file)
plot_audio(trimmed_clip, sample_rate, str(wave_file) + ' trimmed')

plot_spectrogram(clip, sample_rate, 'original')
plot_spectrogram(trimmed_clip, sample_rate, 'trimmed')
# Out:
# Sample Rate   16000 Hz
# Clip Length   1.19 seconds
# Trimmed clip Length   0.17 seconds

# %% [markdown]
# #Index : 9, Class label : 10, Consonant : 'ထ၊ ဌ'

# %%
wave_file = paths[9]

clip, sample_rate = librosa.load(wave_file, sr=None)
print('Sample Rate   {} Hz'.format(sample_rate))
print('Clip Length   {:3.2f} seconds'.format(librosa.get_duration(clip, sample_rate)))

trimmed_clip, _ = librosa.effects.trim(clip, top_db=10, frame_length=256, hop_length=128)
print('Trimmed clip Length   {:3.2f} seconds'.format(librosa.get_duration(trimmed_clip, sample_rate)))

plot_audio(clip, sample_rate, wave_file)
plot_audio(trimmed_clip, sample_rate, str(wave_file) + ' trimmed')

plot_spectrogram(clip, sample_rate, 'original')
plot_spectrogram(trimmed_clip, sample_rate, 'trimmed')
# Out:
# Sample Rate   16000 Hz
# Clip Length   0.99 seconds
# Trimmed clip Length   0.15 seconds

# %% [markdown]
# #Index : 10, Class label : 11, Consonant : 'ဍ၊ ဎ၊ ဒ၊ ဓ'

# %%
wave_file = paths[10]

clip, sample_rate = librosa.load(wave_file, sr=None)
print('Sample Rate   {} Hz'.format(sample_rate))
print('Clip Length   {:3.2f} seconds'.format(librosa.get_duration(clip, sample_rate)))

trimmed_clip, _ = librosa.effects.trim(clip, top_db=10, frame_length=256, hop_length=128)
print('Trimmed clip Length   {:3.2f} seconds'.format(librosa.get_duration(trimmed_clip, sample_rate)))

plot_audio(clip, sample_rate, wave_file)
plot_audio(trimmed_clip, sample_rate, str(wave_file) + ' trimmed')

plot_spectrogram(clip, sample_rate, 'original')
plot_spectrogram(trimmed_clip, sample_rate, 'trimmed')
# Out:
# Sample Rate   16000 Hz
# Clip Length   0.99 seconds
# Trimmed clip Length   0.19 seconds

# %% [markdown]
# #Index : 11, Class label : 12, Consonant : 'ဏ၊ န'

# %%
wave_file = paths[11]

clip, sample_rate = librosa.load(wave_file, sr=None)
print('Sample Rate   {} Hz'.format(sample_rate))
print('Clip Length   {:3.2f} seconds'.format(librosa.get_duration(clip, sample_rate)))

trimmed_clip, _ = librosa.effects.trim(clip, top_db=10, frame_length=256, hop_length=128)
print('Trimmed clip Length   {:3.2f} seconds'.format(librosa.get_duration(trimmed_clip, sample_rate)))

plot_audio(clip, sample_rate, wave_file)
plot_audio(trimmed_clip, sample_rate, str(wave_file) + ' trimmed')

plot_spectrogram(clip, sample_rate, 'original')
plot_spectrogram(trimmed_clip, sample_rate, 'trimmed')
# Out:
# Sample Rate   16000 Hz
# Clip Length   1.19 seconds
# Trimmed clip Length   0.18 seconds

# %% [markdown]
# #Index : 12, Class label : 13, Consonant : 'ပ'

# %%
wave_file = paths[12]

clip, sample_rate = librosa.load(wave_file, sr=None)
print('Sample Rate   {} Hz'.format(sample_rate))
print('Clip Length   {:3.2f} seconds'.format(librosa.get_duration(clip, sample_rate)))

trimmed_clip, _ = librosa.effects.trim(clip, top_db=10, frame_length=256, hop_length=128)
print('Trimmed clip Length   {:3.2f} seconds'.format(librosa.get_duration(trimmed_clip, sample_rate)))

plot_audio(clip, sample_rate, wave_file)
plot_audio(trimmed_clip, sample_rate, str(wave_file) + ' trimmed')

plot_spectrogram(clip, sample_rate, 'original')
plot_spectrogram(trimmed_clip, sample_rate, 'trimmed')
# Out:
# Sample Rate   16000 Hz
# Clip Length   0.96 seconds
# Trimmed clip Length   0.12 seconds

# %% [markdown]
# #Index : 13, Class label : 14, Consonant : 'ဖ'

# %%
wave_file = paths[13]

clip, sample_rate = librosa.load(wave_file, sr=None)
print('Sample Rate   {} Hz'.format(sample_rate))
print('Clip Length   {:3.2f} seconds'.format(librosa.get_duration(clip, sample_rate)))

trimmed_clip, _ = librosa.effects.trim(clip, top_db=10, frame_length=256, hop_length=128)
print('Trimmed clip Length   {:3.2f} seconds'.format(librosa.get_duration(trimmed_clip, sample_rate)))

plot_audio(clip, sample_rate, wave_file)
plot_audio(trimmed_clip, sample_rate, str(wave_file) + ' trimmed')

plot_spectrogram(clip, sample_rate, 'original')
plot_spectrogram(trimmed_clip, sample_rate, 'trimmed')
# Out:
# Sample Rate   16000 Hz
# Clip Length   1.18 seconds
# Trimmed clip Length   0.11 seconds

# %% [markdown]
# #Index : 14, Class label : 15, Consonant : 'ဗ၊ ဘ'

# %%
wave_file = paths[14]

clip, sample_rate = librosa.load(wave_file, sr=None)
print('Sample Rate   {} Hz'.format(sample_rate))
print('Clip Length   {:3.2f} seconds'.format(librosa.get_duration(clip, sample_rate)))

trimmed_clip, _ = librosa.effects.trim(clip, top_db=10, frame_length=256, hop_length=128)
print('Trimmed clip Length   {:3.2f} seconds'.format(librosa.get_duration(trimmed_clip, sample_rate)))

plot_audio(clip, sample_rate, wave_file)
plot_audio(trimmed_clip, sample_rate, str(wave_file) + ' trimmed')

plot_spectrogram(clip, sample_rate, 'original')
plot_spectrogram(trimmed_clip, sample_rate, 'trimmed')
# Out:
# Sample Rate   16000 Hz
# Clip Length   1.39 seconds
# Trimmed clip Length   0.17 seconds

# %% [markdown]
# #Index : 15, Class label : 16, Consonant : 'မ'

# %%
wave_file = paths[15]

clip, sample_rate = librosa.load(wave_file, sr=None)
print('Sample Rate   {} Hz'.format(sample_rate))
print('Clip Length   {:3.2f} seconds'.format(librosa.get_duration(clip, sample_rate)))

trimmed_clip, _ = librosa.effects.trim(clip, top_db=10, frame_length=256, hop_length=128)
print('Trimmed clip Length   {:3.2f} seconds'.format(librosa.get_duration(trimmed_clip, sample_rate)))

plot_audio(clip, sample_rate, wave_file)
plot_audio(trimmed_clip, sample_rate, str(wave_file) + ' trimmed')

plot_spectrogram(clip, sample_rate, 'original')
plot_spectrogram(trimmed_clip, sample_rate, 'trimmed')
# Out:
# Sample Rate   16000 Hz
# Clip Length   1.18 seconds
# Trimmed clip Length   0.17 seconds

# %% [markdown]
# #Index : 16, Class label : 17, Consonant : 'ယ၊ ရ'

# %%
wave_file = paths[16]

clip, sample_rate = librosa.load(wave_file, sr=None)
print('Sample Rate   {} Hz'.format(sample_rate))
print('Clip Length   {:3.2f} seconds'.format(librosa.get_duration(clip, sample_rate)))

trimmed_clip, _ = librosa.effects.trim(clip, top_db=10, frame_length=256, hop_length=128)
print('Trimmed clip Length   {:3.2f} seconds'.format(librosa.get_duration(trimmed_clip, sample_rate)))

plot_audio(clip, sample_rate, wave_file)
plot_audio(trimmed_clip, sample_rate, str(wave_file) + ' trimmed')

plot_spectrogram(clip, sample_rate, 'original')
plot_spectrogram(trimmed_clip, sample_rate, 'trimmed')
# Out:
# Sample Rate   16000 Hz
# Clip Length   0.99 seconds
# Trimmed clip Length   0.14 seconds

# %% [markdown]
# #Index : 17, Class label : 18, Consonant : 'လ၊ ဠ'

# %%
wave_file = paths[17]

clip, sample_rate = librosa.load(wave_file, sr=None)
print('Sample Rate   {} Hz'.format(sample_rate))
print('Clip Length   {:3.2f} seconds'.format(librosa.get_duration(clip, sample_rate)))

trimmed_clip, _ = librosa.effects.trim(clip, top_db=10, frame_length=256, hop_length=128)
print('Trimmed clip Length   {:3.2f} seconds'.format(librosa.get_duration(trimmed_clip, sample_rate)))

plot_audio(clip, sample_rate, wave_file)
plot_audio(trimmed_clip, sample_rate, str(wave_file) + ' trimmed')

plot_spectrogram(clip, sample_rate, 'original')
plot_spectrogram(trimmed_clip, sample_rate, 'trimmed')
# Out:
# Sample Rate   16000 Hz
# Clip Length   1.19 seconds
# Trimmed clip Length   0.14 seconds

# %% [markdown]
# #Index : 18, Class label : 19, Consonant : 'ဝ'

# %%
wave_file = paths[18]

clip, sample_rate = librosa.load(wave_file, sr=None)
print('Sample Rate   {} Hz'.format(sample_rate))
print('Clip Length   {:3.2f} seconds'.format(librosa.get_duration(clip, sample_rate)))

trimmed_clip, _ = librosa.effects.trim(clip, top_db=10, frame_length=256, hop_length=128)
print('Trimmed clip Length   {:3.2f} seconds'.format(librosa.get_duration(trimmed_clip, sample_rate)))

plot_audio(clip, sample_rate, wave_file)
plot_audio(trimmed_clip, sample_rate, str(wave_file) + ' trimmed')

plot_spectrogram(clip, sample_rate, 'original')
plot_spectrogram(trimmed_clip, sample_rate, 'trimmed')
# Out:
# Sample Rate   16000 Hz
# Clip Length   1.18 seconds
# Trimmed clip Length   0.17 seconds

# %% [markdown]
# #Index : 19, Class label : 20, Consonant : 'သ'

# %%
wave_file = paths[19]

clip, sample_rate = librosa.load(wave_file, sr=None)
print('Sample Rate   {} Hz'.format(sample_rate))
print('Clip Length   {:3.2f} seconds'.format(librosa.get_duration(clip, sample_rate)))

trimmed_clip, _ = librosa.effects.trim(clip, top_db=10, frame_length=256, hop_length=128)
print('Trimmed clip Length   {:3.2f} seconds'.format(librosa.get_duration(trimmed_clip, sample_rate)))

plot_audio(clip, sample_rate, wave_file)
plot_audio(trimmed_clip, sample_rate, str(wave_file) + ' trimmed')

plot_spectrogram(clip, sample_rate, 'original')
plot_spectrogram(trimmed_clip, sample_rate, 'trimmed')
# Out:
# Sample Rate   16000 Hz
# Clip Length   1.18 seconds
# Trimmed clip Length   0.14 seconds

# %% [markdown]
# #Index : 20, Class label : 21, Consonant : 'ဟ'

# %%
wave_file = paths[20]

clip, sample_rate = librosa.load(wave_file, sr=None)
print('Sample Rate   {} Hz'.format(sample_rate))
print('Clip Length   {:3.2f} seconds'.format(librosa.get_duration(clip, sample_rate)))

trimmed_clip, _ = librosa.effects.trim(clip, top_db=10, frame_length=256, hop_length=128)
print('Trimmed clip Length   {:3.2f} seconds'.format(librosa.get_duration(trimmed_clip, sample_rate)))

plot_audio(clip, sample_rate, wave_file)
plot_audio(trimmed_clip, sample_rate, str(wave_file) + ' trimmed')

plot_spectrogram(clip, sample_rate, 'original')
plot_spectrogram(trimmed_clip, sample_rate, 'trimmed')
# Out:
# Sample Rate   16000 Hz
# Clip Length   1.18 seconds
# Trimmed clip Length   0.14 seconds

# %% [markdown]
# #Index : 21, Class label : 22, Consonant : 'အ'

# %%
wave_file = paths[21]

clip, sample_rate = librosa.load(wave_file, sr=None)
print('Sample Rate   {} Hz'.format(sample_rate))
print('Clip Length   {:3.2f} seconds'.format(librosa.get_duration(clip, sample_rate)))

trimmed_clip, _ = librosa.effects.trim(clip, top_db=10, frame_length=256, hop_length=128)
print('Trimmed clip Length   {:3.2f} seconds'.format(librosa.get_duration(trimmed_clip, sample_rate)))

plot_audio(clip, sample_rate, wave_file)
plot_audio(trimmed_clip, sample_rate, str(wave_file) + ' trimmed')

plot_spectrogram(clip, sample_rate, 'original')
plot_spectrogram(trimmed_clip, sample_rate, 'trimmed')
# Out:
# Sample Rate   16000 Hz
# Clip Length   1.19 seconds
# Trimmed clip Length   0.14 seconds
